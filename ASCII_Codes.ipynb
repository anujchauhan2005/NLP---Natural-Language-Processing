# %%
'A'
# Out:
# 'A'

# %%
ord('A')
# Out:
# 65

# %%
ord(';')
# Out:
# 59

# %%
ord( ' ')   # space ascii codes
# Out:
# 32

# %%
ord('1')
# Out:
# 49

# %%
ord('N')
# Out:
# 78

# %%
ord('n')
# Out:
# 110

# %%
ord('!')
# Out:
# 33

# %%
name = "Anuj Chauhan"

# %%
for char in name:
  print(ord,ord(char))
# Out:
# <built-in function ord> 65
# <built-in function ord> 110
# <built-in function ord> 117
# <built-in function ord> 106
# <built-in function ord> 32
# <built-in function ord> 67
# <built-in function ord> 104
# <built-in function ord> 97
# <built-in function ord> 117
# <built-in function ord> 104
# <built-in function ord> 97
# <built-in function ord> 110

# %%
print([char for char in name])
[ord(char) for char in name]
# Out:
# ['A', 'n', 'u', 'j', ' ', 'C', 'h', 'a', 'u', 'h', 'a', 'n']
# [65, 110, 117, 106, 32, 67, 104, 97, 117, 104, 97, 110]
