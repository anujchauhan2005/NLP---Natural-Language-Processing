# %%
# synonyms => similar words

Good = Nice

# Antonyms => opposite words]

Good = Bad

# %%
import nltk
nltk.download('wordnet')
from nltk.corpus import wordnet
# Out:
# [nltk_data] Downloading package wordnet to /root/nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!

# %%
syn = wordnet.synsets('book')


syn[0].definition() ### gives the definition of a words
# Out:
# 'a written work or composition that has been published (printed on pages bound together)'

# %% [markdown]
# ## 1. Printing the synonyms

# %%
synonyms = []

for syn in wordnet.synsets('happy'):
  for lemma in syn.lemmas():
    synonyms.append(lemma.name())

synonyms
# Out:
# ['happy', 'felicitous', 'happy', 'glad', 'happy', 'happy', 'well-chosen']

# %% [markdown]
# ## 2. Printing the Antonyms

# %%
antonyms = []

for ant in wordnet.synsets('happy '):
  for l in ant.lemmas():
    if l.antonyms():
      antonyms.append(l.antonyms()[0].name())

antonyms
# Out:
# ['unhappy']

# %% [markdown]
# ## 3. Synonyms + Antonyms Together

# %%
def get_synonyms_antonyms(word):
    synonyms = set()
    antonyms = set()

    for syn in wordnet.synsets(word):
        for lemma in syn.lemmas():
            synonyms.add(lemma.name())

            if lemma.antonyms():
                antonyms.add(lemma.antonyms()[0].name())

    return synonyms, antonyms

# %%
syns, ants = get_synonyms_antonyms("happy")

print("Synonyms:", syns)
print("Antonyms:", ants)
# Out:
# Synonyms: {'happy', 'well-chosen', 'felicitous', 'glad'}
# Antonyms: {'unhappy'}
